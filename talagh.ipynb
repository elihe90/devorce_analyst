# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
amar_df=pd.read_excel('amar_excel_tavafoghi.xlsx')
amar_df
# Out:
#    year  citeis_thran  ostan_thran  all_thran  jen
# 0  1394         28579        11339      39918    1
# 1  1395         30615        11333      41948    1
# 2  1396         33244        11320      44564    1
# 3  1397         27647         9551      37198    1
# 4  1398         16374         9709      26083    1

# %%
#درخواست طلاق توافقی 
#jen=1

# %%
amar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          5 non-null      int64
#  1   citeis_thran  5 non-null      int64
#  2   ostan_thran   5 non-null      int64
#  3   all_thran     5 non-null      int64
#  4   jen           5 non-null      int64
# dtypes: int64(5)
# memory usage: 328.0 bytes

# %%
amar_df.plot(x='year',y='ostan_thran',label=' ostan theran zojeh',figsize=(15,10),linewidth=2)
plt.ylabel('ostan_thran')
plt.title('amar talagh ostan theran  darkhast zojeh ')
plt.legend(loc='upper left')
plt.grid()

# %%
amar_df.plot(x='year',y='citeis_thran',label=' citeis_thran zojeh',figsize=(15,10),linewidth=3)
plt.ylabel('citeis_thran')
plt.ylabel('year')
plt.title('amar talagh citeis_thran zojeh')
plt.legend(loc='upper left')
plt.grid()

# %%
amar1_df=pd.read_excel('amar_excel_zan.xlsx')
amar1_df
# Out:
#    year  citeis_thran  ostan_thran  all_thran  jen
# 0  1394         10337         4702      15039    0
# 1  1395          9902         5027      15017    0
# 2  1396         10021         5013      15034    0
# 3  1397         10829         5661      16490    0
# 4  1398         15864         7324      23188    0

# %%
#درخواست طلاق زوجه 
#jen=0

# %%
amar1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          5 non-null      int64
#  1   citeis_thran  5 non-null      int64
#  2   ostan_thran   5 non-null      int64
#  3   all_thran     5 non-null      int64
#  4   jen           5 non-null      int64
# dtypes: int64(5)
# memory usage: 328.0 bytes

# %%
amar1_df.plot(x='year',y='ostan_thran',label=' ostan theran zojeh',figsize=(15,10),linewidth=2,color='red')
plt.ylabel('ostan_thran')
plt.title('amar talagh ostan theran  darkhast zojeh ')
plt.legend(loc='upper left')
plt.grid()

# %%
amar_df.plot(x='year',y='citeis_thran',label=' citeis_thran zan',figsize=(15,10),linewidth=3,color='red')
plt.ylabel('citeis_thran')
plt.xlabel('year')
plt.title('amar talagh citeis_thran zan')
plt.legend(loc='upper left')
plt.grid()

# %%
y=amar1_df['all_thran']
y
# Out:
# 0    15039
# 1    15017
# 2    15034
# 3    16490
# 4    23188
# Name: all_thran, dtype: int64

# %%
x=amar_df['all_thran']
x
# Out:
# 0    39918
# 1    41948
# 2    44564
# 3    37198
# 4    26083
# Name: all_thran, dtype: int64

# %%
plt.scatter(x,y)
plt.grid()
plt.ylabel('all_thran_tavafoghi')
plt.xlabel('all_thran_zan')
plt.figure(figsize=(40,30))

# %%
 import seaborn as sns

# %%
from mpl_toolkits.mplot3d import Axes3D
# Out:
#   Input In [81]
#     import seaborn as sns
#     ^
# IndentationError: unexpected indent

# %%
amar2_df=pd.read_excel('amar_excel.xlsx')
amar2_df
# Out:
#    year  citeis_thran  ostan_thran  all_thran  jen
# 0  1394         10337         4702      15039    0
# 1  1395         99902         5027      15017    0
# 2  1396         10021         5013      15034    0
# 3  1397         10829         5661      16490    0
# 4  1398         15864         7324      23188    0
# 5  1394            16            5         21    1
# 6  1395             0            0          0    1
# 7  1396             3            1          4    1
# 8  1397             0            2          2    1
# 9  1398             0            4          2    1

# %%
amar2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          10 non-null     int64
#  1   citeis_thran  10 non-null     int64
#  2   ostan_thran   10 non-null     int64
#  3   all_thran     10 non-null     int64
#  4   jen           10 non-null     int64
# dtypes: int64(5)
# memory usage: 528.0 bytes

# %%
plt.figure(figsize=(10,15))
sns.scatterplot(x='citeis_thran',y='ostan_thran',hue='jen',data=amar2_df)
# Out:
# <AxesSubplot:xlabel='citeis_thran', ylabel='ostan_thran'>

# %%
#class 0 =zanan    class 1=mardan

# %%
amar3_df=pd.read_excel('amar_excel_2.xlsx')
amar3_df
# Out:
#    year  citeis_thran  ostan_thran  all_thran  jen
# 0  1394         10337         4702      15039    0
# 1  1395         99902         5027      15017    0
# 2  1396         10021         5013      15034    0
# 3  1397         10829         5661      16490    0
# 4  1398         15864         7324      23188    0
# 5  1394         28579        11339      39918    1
# 6  1395         30615        11333      41948    1
# 7  1396         33244        11320      44564    1
# 8  1397         27647         9551      37198    1
# 9  1398         16374         9709      26083    1

# %%
amar3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          10 non-null     int64
#  1   citeis_thran  10 non-null     int64
#  2   ostan_thran   10 non-null     int64
#  3   all_thran     10 non-null     int64
#  4   jen           10 non-null     int64
# dtypes: int64(5)
# memory usage: 528.0 bytes

# %%
plt.figure(figsize=(10,15))
sns.scatterplot(x='citeis_thran',y='ostan_thran',hue='jen',data=amar3_df)
# Out:
# <AxesSubplot:xlabel='citeis_thran', ylabel='ostan_thran'>

# %%
#class 0 =zanan    class 1=tavafoghi

# %%
sns.pairplot(amar3_df,hue='jen',vars=['year','citeis_thran','ostan_thran','all_thran'])

# %%
plt.figure(figsize=(20,20))
sns.heatmap(amar3_df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
class_0_df=amar3_df[amar3_df['jen']==0 ]
class_1_df=amar3_df[amar3_df['jen']==1 ]

# %%
plt.figure(figsize=(10,7))
sns.distplot(class_0_df['citeis_thran'],bins=1,color='blue')
sns.distplot(class_1_df['ostan_thran'],bins=1,color='red')
plt.grid()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
